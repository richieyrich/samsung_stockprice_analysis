# %% [markdown]
# Samsung Stock Price Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Samsung Dataset.csv')
df
# Out:
#             Date     Open     High      Low    Close     Adj Close    Volume
# 0     2000-01-04   6000.0   6110.0   5660.0   6110.0   4449.709961  74195000
# 1     2000-01-05   5800.0   6060.0   5520.0   5580.0   4063.728760  74680000
# 2     2000-01-06   5750.0   5780.0   5580.0   5620.0   4092.859863  54390000
# 3     2000-01-07   5560.0   5670.0   5360.0   5540.0   4034.598877  40305000
# 4     2000-01-10   5600.0   5770.0   5580.0   5770.0   4202.098145  46880000
# ...          ...      ...      ...      ...      ...           ...       ...
# 6122  2024-06-07  78400.0  78600.0  77100.0  77300.0  77300.000000  21189349
# 6123  2024-06-10  76100.0  76600.0  75600.0  75700.0  75700.000000  14598755
# 6124  2024-06-11  75900.0  76000.0  75100.0  75200.0  75200.000000  16971175
# 6125  2024-06-12  75300.0  77100.0  75200.0  76500.0  76500.000000  19246725
# 6126  2024-06-13  78400.0  79000.0  77800.0  78600.0  78600.000000  33763804
#
# [6127 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6127 entries, 0 to 6126
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6127 non-null   datetime64[ns]
#  1   Open       6127 non-null   float64
#  2   High       6127 non-null   float64
#  3   Low        6127 non-null   float64
#  4   Close      6127 non-null   float64
#  5   Adj Close  6127 non-null   float64
#  6   Volume     6127 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 335.2 KB

# %%
df.nunique()
# Out:
# Date         6127
# Open         2127
# High         2209
# Low          2234
# Close        2185
# Adj Close    3924
# Volume       5884
# dtype: int64

# %%
df.describe()
# Out:
#                                 Date          Open          High  \
# count                           6127   6127.000000   6127.000000
# mean   2012-01-28 09:53:12.231108352  28370.058756  28644.142321
# min              2000-01-04 00:00:00   2540.000000   2760.000000
# 25%              2005-11-16 12:00:00  10700.000000  10900.000000
# 50%              2011-12-27 00:00:00  21020.000000  21420.000000
# 75%              2018-03-20 12:00:00  45590.000000  46100.000000
# max              2024-06-13 00:00:00  90300.000000  96800.000000
# std                              NaN  22589.409269  22764.800972
#
#                 Low         Close     Adj Close        Volume
# count   6127.000000   6127.000000   6127.000000  6.127000e+03
# mean   28084.267994  28360.006528  24504.066849  2.117578e+07
# min     2420.000000   2730.000000   1988.168701  0.000000e+00
# 25%    10560.000000  10720.000000   7901.645264  1.169668e+07
# 50%    20740.000000  21060.000000  16245.702148  1.715000e+07
# ...

# %% [markdown]
# change the date object to datetime format

# %%
# change the date object to datetime format
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6127 entries, 0 to 6126
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6127 non-null   datetime64[ns]
#  1   Open       6127 non-null   float64
#  2   High       6127 non-null   float64
#  3   Low        6127 non-null   float64
#  4   Close      6127 non-null   float64
#  5   Adj Close  6127 non-null   float64
#  6   Volume     6127 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 335.2 KB

# %% [markdown]
# check for null values

# %%
# checking null values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# plot a line chart of price and date

# %%
# line chart of price and date
plt.figure(figsize=(16,7))
plt.plot( df['Date'], df['Close'])
plt.plot( df['Date'], df['Open'], c='r', alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Samsung Price')
plt.show()

# %% [markdown]
# since 2016, samsung has huge uptrend in the stocprice

# %% [markdown]
# analyse 2016 to 2024 chart

# %%
# line chart of price and date
plt.figure(figsize=(16,7))
plt.plot( df['Date'], df['Close'])
plt.plot( df['Date'], df['High'], c='r', alpha=0.5, label = 'highest price')
plt.plot( df['Date'], df['Low'], c='g', alpha=0.5, label = 'lowest price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.xlim(pd.to_datetime('2016-01-01'), pd.to_datetime('2024-01-01'))
plt.title('Samsung Price')
plt.show()

# %% [markdown]
# plot a barplot showing the volume trading

# %%
# bar chart of volume
plt.figure(figsize=(16,7))
sns.barplot(data= df, x='Date', y='Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Samsung stock Volume')
plt.show()

# %% [markdown]
# plot a histogram of closing price

# %%
plt.figure(figsize=(16,7))
sns.histplot(data= df, x='Close', bins=20)
# plt.xlabel('Date')
# plt.ylabel('Close')
plt.title('Samsung stock closing price')
plt.show()

# %%
plt.figure(figsize=(16,7))
sns.histplot(data= df, x='Volume', bins=20)
plt.title('Samsung stock Volume')
plt.show()

# %% [markdown]
# scatterplot on date and volumes

# %%
plt.figure(figsize=(16,7))
sns.scatterplot( x= df['Date'], y= df['Volume'] )
plt.title('highest volume traded')
plt.show()

# %% [markdown]
# find the correlation between different columns to understand how they are related.

# %%
corrltn = df.corr()
corrltn
# Out:
#                Date      Open      High       Low     Close  Adj Close  \
# Date       1.000000  0.921614  0.921750  0.921579  0.921791   0.903514
# Open       0.921614  1.000000  0.999888  0.999914  0.999782   0.996265
# High       0.921750  0.999888  1.000000  0.999882  0.999906   0.996308
# Low        0.921579  0.999914  0.999882  1.000000  0.999902   0.996400
# Close      0.921791  0.999782  0.999906  0.999902  1.000000   0.996413
# Adj Close  0.903514  0.996265  0.996308  0.996400  0.996413   1.000000
# Volume    -0.505680 -0.371244 -0.368713 -0.373160 -0.371162  -0.342241
#
#              Volume
# Date      -0.505680
# Open      -0.371244
# High      -0.368713
# Low       -0.373160
# Close     -0.371162
# Adj Close -0.342241
# Volume     1.000000

# %%
sns.heatmap(corrltn, annot=True, lw=0.5)
plt.title('correlation between different columns')
plt.show()
